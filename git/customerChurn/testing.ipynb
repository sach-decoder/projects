# %%
import pandas as pd

json_data = [
    {"Name": "Alice", "Email": "alice@example.com", "Age": 25},
    {"Name": "Bob", "Email": "bob@example.com", "Age": 30},
    {"Name": "Charlie", "Email": "charlie@example.com", "Age": 35}
]

df = pd.DataFrame(json_data)
df[3]= ["hello", "dbdbwdjiwndjw@gmail.com", 30]
df.loc[len(df)] = ["ifbsfuejf", "iufeuifhef", 20]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 11
#       9 df = pd.DataFrame(json_data)
#      10 df[3]= ["hello", "dbdbwdjiwndjw@gmail.com", 30]
# ---> 11 df.loc[len(df)] = ["ifbsfuejf", "iufeuifhef", 20]
#
# File c:\Users\sachi\.virtualenvs\housePredict-tswQvzyo\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\sachi\.virtualenvs\housePredict-tswQvzyo\Lib\site-packages\pandas\core\indexing.py:1943, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1940     indexer, missing = convert_missing_indexer(indexer)
#    1942     if missing:
# -> 1943         self._setitem_with_indexer_missing(indexer, value)
#    1944         return
#    1946 if name == "loc":
#    1947     # must come after setting of missing
#
# File c:\Users\sachi\.virtualenvs\housePredict-tswQvzyo\Lib\site-packages\pandas\core\indexing.py:2298, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2295     if is_list_like_indexer(value):
#    2296         # must have conforming columns
#    2297         if len(value) != len(self.obj.columns):
# -> 2298             raise ValueError("cannot set a row with mismatched columns")
#    2300     value = Series(value, index=self.obj.columns, name=indexer)
#    2302 if not len(self.obj):
#    2303     # We will ignore the existing dtypes instead of using
#    2304     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns
